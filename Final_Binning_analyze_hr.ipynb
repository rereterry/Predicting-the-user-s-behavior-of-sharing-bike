# %%
from __future__ import print_function
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
import warnings
warnings.filterwarnings('ignore')
# Out:
# /Users/pipiterry/anaconda/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import os.path
userhome = os.path.expanduser('~')
csvfile = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '01-m-00000')
df = pd.read_csv(csvfile,header =None)

# %%
df.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit','temp','atemp','hum','windspeed','casual','registered','cnt']

# %%
#df.columns[5]
x =(df.casual)
y =(df.registered)
z =(df.weekday)
plt.figure(figsize=(8,4))
plt.plot(z,y,'o',label="$registered rider$",color="red")
plt.plot(z,x,'o',color="blue",label="$casual rider$")
plt.xlabel("weekday")
plt.ylabel("number of people")
plt.title("R&C situation")
plt.show()

# %%
# The slices will be ordered and plotted counter-clockwise.
labels = df.holiday
sizes = df.cnt

plt.pie(sizes, labels=labels,
        autopct='%1.1f%%', shadow=True, startangle=90)
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')

plt.show()

# %%
csvfile2 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '02-m-00000')
df2 = pd.read_csv(csvfile2,header =None)
df2.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']

sns.distplot(df2['cnt'])

# %%
sns.distplot(df['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '03-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '04-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '05-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '06-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '07-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '08-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '09-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '10-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '11-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '12-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '13-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '14-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '15-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '16-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '17-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '18-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '19-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '20-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '21-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '22-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '23-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfile3 = os.path.join(userhome, 'Desktop', '2017spring', 'MyJava', 'info7275_final', 'output_Binning', '24-m-00000')
df3 = pd.read_csv(csvfile3,header =None)
df3.columns = ['instant','dteday','season','yr','mnth','hr','holiday','weekday','workingday','weathersit'
              ,'temp','atemp','hum','windspeed','casual','registered','cnt']
sns.distplot(df3['cnt'])

# %%
csvfilex = os.path.join(userhome, 'Desktop', 'Bike-Sharing-Dataset', 'day.csv')
dfx = pd.read_csv(csvfilex)
ax1=sns.kdeplot(dfx['cnt'][dfx['holiday']==0],color='r')
ax2=sns.kdeplot(dfx['cnt'][dfx['holiday']==1],color='b')
plt.show()

# %%
ax1=sns.kdeplot(df['cnt'][df['holiday']==0],color='r')
ax2=sns.kdeplot(df['cnt'][df['holiday']==1],color='b')
plt.show()

# %%
ax1=sns.kdeplot(df2['cnt'][df2['holiday']==0],color='r')
ax2=sns.kdeplot(df2['cnt'][df2['holiday']==1],color='b')
plt.show()

# %%
ax1=sns.kdeplot(df3['cnt'][df3['holiday']==0],color='r')
ax2=sns.kdeplot(df3['cnt'][df3['holiday']==1],color='b')
plt.show()
